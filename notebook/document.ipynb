# %% [markdown]
# data ingestion and data loaders

# %%
# Import Document class
from langchain_core.documents import Document

# Example Document object
doc = Document(
    page_content="This is the main text content I am Using To create Rag Applications",
    metadata={
        "source": "vishal.txt",
        "Author": "Vishal Rajput",
        "pages": 2,
        "date_created": "2026-03-13"
    }
)

print(doc)
# Out:
# page_content='This is the main text content I am Using To create Rag Applications' metadata={'source': 'vishal.txt', 'Author': 'Vishal Rajput', 'pages': 2, 'date_created': '2026-03-13'}

# %%
import os

os.makedirs("../data/text_value", exist_ok=True)

sample_text = {
    "../data/text_value/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.
""",

    "../data/text_value/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed.

Types of Machine Learning:
1. Supervised Learning
2. Unsupervised Learning
3. Reinforcement Learning

Applications include image recognition, speech processing, and recommendation systems.
"""
}

for filepath, content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully")
# Out:
# Sample text files created successfully

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_value/python_intro.txt", encoding="utf-8")

documents = loader.load()

print(documents)
# Out:
# [Document(metadata={'source': '../data/text_value/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_value",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=True
)

documents = dir_loader.load()
print(documents)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 715.69it/s]
# [Document(metadata={'source': '..\\data\\text_value\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed.\n\nTypes of Machine Learning:\n1. Supervised Learning\n2. Unsupervised Learning\n3. Reinforcement Learning\n\nApplications include image recognition, speech processing, and recommendation systems.\n'), Document(metadata={'source': '..\\data\\text_value\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.\n')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader

pdf_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)

pdf_reader = pdf_loader.load()

print(pdf_reader)
# Out:
# Error loading file ..\data\pdf\OOP notes.pdf
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\parsers\pdf.py:954, in PyMuPDFParser._lazy_parse(self, blob, text_kwargs)
#     953 try:
# --> 954     import pymupdf
#     956     text_kwargs = text_kwargs or self.text_kwargs
#
# ModuleNotFoundError: No module named 'pymupdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[110], line 11
#       1 from langchain_community.document_loaders import PyMuPDFLoader
#       3 pdf_loader = DirectoryLoader(
#       4     "../data/pdf",
#       5     glob="**/*.pdf",
#    (...)      8     show_progress=False
#       9 )
# ---> 11 pdf_reader = pdf_loader.load()
#      13 print(pdf_reader)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\directory.py:233, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     231     else:
#     232         logger.error(f"Error loading file {str(item)}")
# --> 233         raise e
#     234 finally:
#     235     if pbar:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\pdf.py:856, in PyMuPDFLoader.lazy_load(self)
#     855 def lazy_load(self) -> Iterator[Document]:
# --> 856     yield from self._lazy_load()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\pdf.py:850, in PyMuPDFLoader._lazy_load(self, **kwargs)
#     848 else:
#     849     blob = Blob.from_path(self.file_path)
# --> 850 yield from parser._lazy_parse(blob, text_kwargs=kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\parsers\pdf.py:991, in PyMuPDFParser._lazy_parse(self, blob, text_kwargs)
#     965         self.extract_tables_settings = {
#     966             # See https://pymupdf.readthedocs.io/en/latest/page.html#Page.find_tables
#     967             "clip": None,
#    (...)    988             "add_lines": None,  # optional user-specified lines
#     989         }
#     990 except ImportError:
# --> 991     raise ImportError(
#     992         "pymupdf package not found, please install it "
#     993         "with `pip install pymupdf`"
#     994     )
#     996 with PyMuPDFParser._lock:
#     997     with blob.as_bytes_io() as file_path:
#
# ImportError: pymupdf package not found, please install it with `pip install pymupdf`

# %%
type(pdf_loader[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 type(pdf_loader[0])
#
# TypeError: 'DirectoryLoader' object is not subscriptable
