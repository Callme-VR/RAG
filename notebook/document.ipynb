# %% [markdown]
# data ingestion and data loaders

# %%
# Import Document class
from langchain_core.documents import Document

# Example Document object
doc = Document(
    page_content="This is the main text content I am Using To create Rag Applications",
    metadata={
        "source": "vishal.txt",
        "Author": "Vishal Rajput",
        "pages": 2,
        "date_created": "2026-03-13"
    }
)

print(doc)
# Out:
# page_content='This is the main text content I am Using To create Rag Applications' metadata={'source': 'vishal.txt', 'Author': 'Vishal Rajput', 'pages': 2, 'date_created': '2026-03-13'}

# %%
import os

os.makedirs("../data/text_value", exist_ok=True)

sample_text = {
    "../data/text_value/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.
""",

    "../data/text_value/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed.

Types of Machine Learning:
1. Supervised Learning
2. Unsupervised Learning
3. Reinforcement Learning

Applications include image recognition, speech processing, and recommendation systems.
"""
}

for filepath, content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully")
# Out:
# Sample text files created successfully

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_value/python_intro.txt", encoding="utf-8")

documents = loader.load()

print(documents)
# Out:
# [Document(metadata={'source': '../data/text_value/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_value",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_value\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed.\n\nTypes of Machine Learning:\n1. Supervised Learning\n2. Unsupervised Learning\n3. Reinforcement Learning\n\nApplications include image recognition, speech processing, and recommendation systems.\n'), Document(metadata={'source': '..\\data\\text_value\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web develo
# ...

# %%
# First install the required package
# !pip install pymupdf

from langchain_community.document_loaders import PyMuPDFLoader

# Remove the encoding parameter as it's not supported by PyMuPDFLoader
pdf_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_reader = pdf_loader.load()

print(pdf_reader)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pymupdf-1.27.2-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.2 MB 2.6 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/19.2 MB 2.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.1/19.2 MB 3.1 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/19.2 MB 3.7 MB/s eta 0:00:05
#    --------- ------------------------------ 4.5/19.2 MB 4.3 MB/s eta 0:00:04
#    ------------- -------------------------- 6.6/19.2 MB 5.2 MB/s eta 0:00:03
#    ------------------- -------------------- 9.2/19.2 MB 6.3 MB/s eta 0:00:02
#    ------------------------- -------------- 12.3/19.2 MB 7.4 MB/s eta 0:00:01
# ...

# %%
# After loading, you can check the type of individual documents
# Note: pdf_loader is a DirectoryLoader, not subscriptable
# pdf_reader contains the loaded documents

print(f"Type of pdf_loader: {type(pdf_loader)}")
print(f"Type of pdf_reader: {type(pdf_reader)}")
print(f"Number of documents loaded: {len(pdf_reader)}")

if pdf_reader:
    print(f"Type of first document: {type(pdf_reader[0])}")
    print(f"First document metadata: {pdf_reader[0].metadata}")
    print(f"First document content preview: {pdf_reader[0].page_content[:200]}...")
# Out:
# Type of pdf_loader: <class 'langchain_community.document_loaders.directory.DirectoryLoader'>
# Type of pdf_reader: <class 'list'>
# Number of documents loaded: 20
# Type of first document: <class 'langchain_core.documents.base.Document'>
# First document metadata: {'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\OOP notes.pdf', 'file_path': '..\\data\\pdf\\OOP notes.pdf', 'total_pages': 20, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-12-19T03:21:45+00:00', 'trapped': '', 'modDate': 'D:20231219032145Z', 'creationDate': '', 'page': 0}
# First document content preview: ...
